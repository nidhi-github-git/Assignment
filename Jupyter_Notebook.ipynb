# %% [markdown]
# <center>
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DS0105EN-SkillsNetwork/labs/Module2/images/SN_web_lightmode.png" width="300" alt="cognitiveclass.ai logo"  />
# </center>

# %% [markdown]
# #### Add your code below following the instructions given in the course

# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# **Nidhi Prabhu Dessai**
#
# I am currently a student and willing to be a data analyst in the healthcare sector.

# %% [markdown]
# _I am interested in data science because there is a growing demand as a career in this field. They are also paid well. And i always loved to work in the IT sector and learn new softwares._

# %% [markdown]
# ### the code below will show some basic mathematics

# %%
print(10+22)
# Out:
# 32

# %% [markdown]
# Horizontal line
# ___

# %% [markdown]
# Bulleted list
# - a
# - b
# - c

# %% [markdown]
# Numbered list
# 1. apple
# 2. ball
# 3. cat

# %% [markdown]
# A table
# |Sr no| marks |
# |---|---|
# |1|35|
# |2|40|

# %% [markdown]
# Hyperlink
#
# [Importance of data](https://www.c-q-l.org/resources/guides/12-reasons-why-data-is-important/#:~:text=Good%20data%20allows%20organizations%20to,a%20particular%20solution%20is%20implemented.)
